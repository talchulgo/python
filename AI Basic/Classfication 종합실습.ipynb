# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from glob import glob
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#root_dir = "D:/data/NEU Metal Surface Defects Data"
root_dir = 'C:/Users/poscoedu_ph/AI 기초/data/NEU Metal Surface Defects Data'
os.listdir(root_dir + '/train')

os.listdir(root_dir + '/train/Inclusion')
# Out:
# ['In_120.bmp',
#  'In_121.bmp',
#  'In_122.bmp',
#  'In_123.bmp',
#  'In_124.bmp',
#  'In_125.bmp',
#  'In_126.bmp',
#  'In_127.bmp',
#  'In_128.bmp',
#  'In_129.bmp',
#  'In_13.bmp',
#  'In_130.bmp',
#  'In_131.bmp',
#  'In_132.bmp',
#  'In_133.bmp',
#  'In_134.bmp',
#  'In_135.bmp',
#  'In_136.bmp',
#  'In_137.bmp',
#  'In_138.bmp',
#  'In_139.bmp',
#  'In_14.bmp',
#  'In_140.bmp',
#  'In_141.bmp',
#  'In_142.bmp',
#  'In_143.bmp',
#  'In_144.bmp',
#  'In_145.bmp',
#  'In_146.bmp',
#  'In_147.bmp',
#  'In_148.bmp',
#  'In_149.bmp',
#  'In_15.bmp',
#  'In_150.bmp',
#  'In_151.bmp',
#  'In_152.bmp',
#  'In_153.bmp',
#  'In_154.bmp',
#  'In_155.bmp',
#  'In_156.bmp',
#  'In_157.bmp',
#  'In_158.bmp',
#  'In_159.bmp',
#  'In_16.bmp',
#  'In_160.bmp',
#  'In_161.bmp',
#  'In_162.bmp',
#  'In_163.bmp',
#  'In_164.bmp',
#  'In_165.bmp',
#  'In_166.bmp',
#  'In_167.bmp',
#  'In_168.bmp',
#  'In_169.bmp',
#  'In_17.bmp',
#  'In_170.bmp',
#  'In_171.bmp',
#  'In_172.bmp',
#  'In_173.bmp',
#  'In_174.bmp',
#  'In_175.bmp',
#  'In_176.bmp',
#  'In_177.bmp',
#  'In_178.bmp',
#  'In_179.bmp',
#  'In_18.bmp',
#  'In_180.bmp',
#  'In_181.bmp',
#  'In_182.bmp',
#  'In_183.bmp',
#  'In_184.bmp',
#  'In_185.bmp',
#  'In_186.bmp',
#  'In_187.bmp',
#  'In_188.bmp',
#  'In_189.bmp',
#  'In_19.bmp',
#  'In_190.bmp',
#  'In_191.bmp',
#  'In_192.bmp',
#  'In_193.bmp',
#  'In_194.bmp',
#  'In_195.bmp',
#  'In_196.bmp',
#  'In_197.bmp',
#  'In_198.bmp',
#  'In_199.bmp',
#  'In_2.bmp',
#  'In_20.bmp',
#  'In_200.bmp',
#  'In_201.bmp',
#  'In_202.bmp',
#  'In_203.bmp',
#  'In_204.bmp',
#  'In_205.bmp',
#  'In_206.bmp',
#  'In_207.bmp',
#  'In_208.bmp',
#  'In_209.bmp',
#  'In_21.bmp',
#  'In_210.bmp',
#  'In_211.bmp',
#  'In_212.bmp',
#  'In_213.bmp',
#  'In_214.bmp',
#  'In_215.bmp',
#  'In_216.bmp',
#  'In_217.bmp',
#  'In_218.bmp',
#  'In_219.bmp',
#  'In_22.bmp',
#  'In_220.bmp',
#  'In_221.bmp',
#  'In_222.bmp',
#  'In_223.bmp',
#  'In_224.bmp',
#  'In_225.bmp',
#  'In_226.bmp',
#  'In_227.bmp',
#  'In_228.bmp',
#  'In_229.bmp',
#  'In_23.bmp',
#  'In_230.bmp',
#  'In_231.bmp',
#  'In_232.bmp',
#  'In_233.bmp',
#  'In_234.bmp',
#  'In_235.bmp',
#  'In_236.bmp',
#  'In_237.bmp',
#  'In_238.bmp',
#  'In_239.bmp',
#  'In_24.bmp',
#  'In_240.bmp',
#  'In_241.bmp',
#  'In_242.bmp',
#  'In_243.bmp',
#  'In_244.bmp',
#  'In_245.bmp',
#  'In_246.bmp',
#  'In_247.bmp',
#  'In_248.bmp',
#  'In_249.bmp',
#  'In_25.bmp',
#  'In_250.bmp',
#  'In_251.bmp',
#  'In_252.bmp',
#  'In_253.bmp',
#  'In_254.bmp',
#  'In_255.bmp',
#  'In_256.bmp',
#  'In_257.bmp',
#  'In_258.bmp',
#  'In_259.bmp',
#  'In_26.bmp',
#  'In_260.bmp',
#  'In_261.bmp',
#  'In_262.bmp',
#  'In_263.bmp',
#  'In_264.bmp',
#  'In_265.bmp',
#  'In_266.bmp',
#  'In_267.bmp',
#  'In_268.bmp',
#  'In_269.bmp',
#  'In_27.bmp',
#  'In_270.bmp',
#  'In_271.bmp',
#  'In_272.bmp',
#  'In_273.bmp',
#  'In_274.bmp',
#  'In_275.bmp',
#  'In_276.bmp',
#  'In_277.bmp',
#  'In_278.bmp',
#  'In_279.bmp',
#  'In_28.bmp',
#  'In_280.bmp',
#  'In_281.bmp',
#  'In_282.bmp',
#  'In_283.bmp',
#  'In_284.bmp',
#  'In_285.bmp',
#  'In_286.bmp',
#  'In_287.bmp',
#  'In_288.bmp',
#  'In_289.bmp',
#  'In_29.bmp',
#  'In_290.bmp',
#  'In_291.bmp',
#  'In_292.bmp',
#  'In_293.bmp',
#  'In_294.bmp',
#  'In_295.bmp',
#  'In_296.bmp',
#  'In_297.bmp',
#  'In_298.bmp',
#  'In_299.bmp',
#  'In_3.bmp',
#  'In_30.bmp',
#  'In_300.bmp',
#  'In_31.bmp',
#  'In_32.bmp',
#  'In_33.bmp',
#  'In_34.bmp',
#  'In_35.bmp',
#  'In_36.bmp',
#  'In_37.bmp',
#  'In_38.bmp',
#  'In_39.bmp',
#  'In_4.bmp',
#  'In_40.bmp',
#  'In_41.bmp',
#  'In_42.bmp',
#  'In_43.bmp',
#  'In_44.bmp',
#  'In_45.bmp',
#  'In_46.bmp',
#  'In_47.bmp',
#  'In_48.bmp',
#  'In_49.bmp',
#  'In_5.bmp',
#  'In_50.bmp',
#  'In_51.bmp',
#  'In_52.bmp',
#  'In_53.bmp',
#  'In_54.bmp',
#  'In_55.bmp',
#  'In_56.bmp',
#  'In_57.bmp',
#  'In_58.bmp',
#  'In_59.bmp',
#  'In_6.bmp',
#  'In_60.bmp',
#  'In_61.bmp',
#  'In_62.bmp',
#  'In_63.bmp',
#  'In_64.bmp',
#  'In_65.bmp',
#  'In_66.bmp',
#  'In_67.bmp',
#  'In_68.bmp',
#  'In_69.bmp',
#  'In_7.bmp',
#  'In_70.bmp',
#  'In_71.bmp',
#  'In_72.bmp',
#  'In_73.bmp',
#  'In_74.bmp',
#  'In_75.bmp',
#  'In_76.bmp',
#  'In_77.bmp',
#  'In_78.bmp',
#  'In_79.bmp',
#  'In_8.bmp',
#  'In_80.bmp',
#  'In_81.bmp',
#  'In_82.bmp',
#  'In_83.bmp',
#  'In_84.bmp',
#  'In_85.bmp',
#  'In_86.bmp',
#  'In_87.bmp',
#  'In_88.bmp',
#  'In_89.bmp',
#  'In_9.bmp',
#  'In_90.bmp',
#  'In_91.bmp',
#  'In_92.bmp',
#  'In_93.bmp',
#  'In_94.bmp',
#  'In_95.bmp',
#  'In_96.bmp',
#  'In_97.bmp',
#  'In_98.bmp',
#  'In_99.bmp']

# %%
train_dir = root_dir + '/train'
val_dir = root_dir + '/valid'
test_dir = root_dir + '/test'

labels = os.listdir(train_dir)
labels
# Out:
# ['Crazing', 'Inclusion', 'Patches', 'Pitted', 'Rolled', 'Scratches']

# %%
for label in labels:
    print('{}:{}개'.format(label,len(os.listdir(train_dir+'/'+label ))))
# Out:
# Crazing:276개
# Inclusion:276개
# Patches:276개
# Pitted:276개
# Rolled:276개
# Scratches:276개

# %%
img_file_list = os.listdir(train_dir+"/"+labels[0]+"/") # crazing 파일 리스트 
img_file = train_dir+"/"+labels[0]+"/"+img_file_list[0] # 1번째 사진
image_pil = Image.open(img_file)
print(image_pil.filename)
print(image_pil.filename.split('/')[-1])
image_pil
# Out:
# C:/Users/poscoedu_ph/AI 기초/data/NEU Metal Surface Defects Data/train/Crazing/Cr_120.bmp
# Cr_120.bmp
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=200x200 at 0x24C2D19D460>

# %%
image = np.array(image_pil)
print(image.shape)
image
# Out:
# (200, 200)
# array([[141, 131, 126, ..., 149, 158, 172],
#        [106, 125, 114, ..., 149, 158, 194],
#        [118, 113,  82, ..., 163, 159, 175],
#        ...,
#        [167, 176, 145, ..., 146, 139, 125],
#        [131, 146, 152, ..., 139, 140, 139],
#        [122, 139, 140, ..., 148, 150, 122]], dtype=uint8)

# %%
plt.imshow(image, "gray")
plt.show()

# %%
# Defects 클래스별 첫번째 이미지 확인

for label in labels:
    img_file_list = os.listdir(train_dir+"/"+label+"/")
    img_file = train_dir+"/"+label+"/"+img_file_list[0]
    image_pil = Image.open(img_file)
    image = np.array(image_pil)
    print(image_pil.filename.split('/')[-1]) 
    plt.imshow(image, "gray")
    plt.show()
# Out:
# Cr_120.bmp
# In_120.bmp
# Pa_120.bmp
# PS_120.bmp
# RS_120.bmp
# Sc_120.bmp

# %%
# 이미지를 ndarray 묶음으로 변환

# 입력 데이터를 ndarray로 변환하는 사용자 함수 선언

def makeTrainData(image_dir):
    x_list = None
    y_list = None
    cnt = 0
    
    for label_no, label_dir in enumerate(os.listdir(image_dir)):
        for file in os.listdir(image_dir + "/" + label_dir):
            cnt += 1
            print("처리중...({})".format(cnt), end="\r") # im 다른 모드 변환 이미지반환(RGB, CMYK, L(256단계 흑백 이미지), 1(단색 이미지)
            this_img = np.array(Image.open(image_dir + "/" + label_dir + "/" + file).convert("RGB"))
            this_img = np.expand_dims(this_img, axis=0) # 1번째 축에 차원 추가
            if x_list is None:
                x_list = this_img
            else:
                x_list = np.vstack([x_list, this_img])
                
            this_label = np.zeros(shape=(1,6))
            this_label[0, label_no] = 1
            if y_list is None:
                y_list = this_label
            else:
                y_list = np.vstack([y_list, this_label])
    
    x_list =x_list / 255.  # 데이터 정규화
    return x_list, y_list

# %%
x_train, y_train = makeTrainData(train_dir)
x_train.shape, y_train.shape
# Out:
# 처리중...(1656)
# ((1656, 200, 200, 3), (1656, 6))

# %%
x_val, y_val = makeTrainData(val_dir)
x_val.shape, y_val.shape
# Out:
# 처리중...(72)
# ((72, 200, 200, 3), (72, 6))

# %%
y_train[276]
# Out:
# array([0., 1., 0., 0., 0., 0.])

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(input_shape=(200,200,3), kernel_size=(3,3),filters=32, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),
    
    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=64, padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),

    tf.keras.layers.Conv2D(kernel_size=(3,3), filters=128, padding='same',activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=(2,2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(rate=0.3),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 200, 200, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 80000)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               40960512
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 41,186,630
# Trainable params: 41,186,630
# Non-trainable params: 0
# _________________________________________________________________

# %%
32*3*3*64+64
# Out:
# 18496

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train, epochs=25, batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/25
# 52/52 [==============================] - 7s 58ms/step - loss: 1.7741 - accuracy: 0.2880 - val_loss: 1.2610 - val_accuracy: 0.3472
# Epoch 2/25
# 52/52 [==============================] - 2s 44ms/step - loss: 0.9783 - accuracy: 0.5984 - val_loss: 0.7596 - val_accuracy: 0.6667
# Epoch 3/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.6849 - accuracy: 0.7434 - val_loss: 0.4525 - val_accuracy: 0.8750
# Epoch 4/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.6117 - accuracy: 0.7820 - val_loss: 0.3449 - val_accuracy: 0.9167
# Epoch 5/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.3361 - accuracy: 0.8798 - val_loss: 0.1856 - val_accuracy: 0.9306
# Epoch 6/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.2936 - accuracy: 0.8931 - val_loss: 0.1804 - val_accuracy: 0.9306
# Epoch 7/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.1811 - accuracy: 0.9348 - val_loss: 0.1844 - val_accuracy: 0.9306
# Epoch 8/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1552 - accuracy: 0.9463 - val_loss: 0.2257 - val_accuracy: 0.9167
# Epoch 9/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1351 - accuracy: 0.9583 - val_loss: 0.5917 - val_accuracy: 0.8333
# Epoch 10/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.2627 - accuracy: 0.9124 - val_loss: 0.2447 - val_accuracy: 0.9444
# Epoch 11/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1140 - accuracy: 0.9638 - val_loss: 0.1856 - val_accuracy: 0.9444
# Epoch 12/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1065 - accuracy: 0.9662 - val_loss: 0.1026 - val_accuracy: 0.9722
# Epoch 13/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1540 - accuracy: 0.9499 - val_loss: 0.2831 - val_accuracy: 0.9306
# Epoch 14/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.2573 - accuracy: 0.9155 - val_loss: 0.0738 - val_accuracy: 0.9583
# Epoch 15/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.0684 - accuracy: 0.9764 - val_loss: 0.1962 - val_accuracy: 0.9583
# Epoch 16/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1221 - accuracy: 0.9620 - val_loss: 0.1238 - val_accuracy: 0.9722
# Epoch 17/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1067 - accuracy: 0.9674 - val_loss: 0.0928 - val_accuracy: 0.9444
# Epoch 18/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1064 - accuracy: 0.9632 - val_loss: 0.1572 - val_accuracy: 0.9722
# Epoch 19/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.1984 - accuracy: 0.9384 - val_loss: 0.1993 - val_accuracy: 0.9444
# Epoch 20/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.0702 - accuracy: 0.9795 - val_loss: 0.1394 - val_accuracy: 0.9444
# Epoch 21/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.0971 - accuracy: 0.9686 - val_loss: 0.1048 - val_accuracy: 0.9722
# Epoch 22/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.0871 - accuracy: 0.9734 - val_loss: 0.0947 - val_accuracy: 0.9722
# Epoch 23/25
# 52/52 [==============================] - 2s 43ms/step - loss: 0.0598 - accuracy: 0.9825 - val_loss: 0.0469 - val_accuracy: 0.9722
# Epoch 24/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.0479 - accuracy: 0.9891 - val_loss: 0.0559 - val_accuracy: 0.9722
# Epoch 25/25
# 52/52 [==============================] - 2s 42ms/step - loss: 0.0372 - accuracy: 0.9897 - val_loss: 0.1552 - val_accuracy: 0.9167

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], 'b-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7,1)
plt.legend()

plt.show()

# %%
save_path = 'my_model.h5'
model.save(save_path, include_optimizer=True)

# %%
# 모델 블러오기 
model = tf.keras.models.load_model('my_model.h5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 200, 200, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 80000)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               40960512
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 41,186,630
# Trainable params: 41,186,630
# Non-trainable params: 0
# _________________________________________________________________

# %%
img_file_list = os.listdir(test_dir+"/"+labels[0]+"/")
img_file_list
# Out:
# ['Cr_1.bmp',
#  'Cr_10.bmp',
#  'Cr_100.bmp',
#  'Cr_101.bmp',
#  'Cr_102.bmp',
#  'Cr_103.bmp',
#  'Cr_104.bmp',
#  'Cr_105.bmp',
#  'Cr_106.bmp',
#  'Cr_107.bmp',
#  'Cr_108.bmp',
#  'Cr_109.bmp']

# %%
img_file = test_dir+"/"+labels[0]+"/"+img_file_list[0]
image_pil = Image.open(img_file).convert("RGB") #컬러 이미지로 불러오기
image_pil
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x24E259FD8B0>

# %%
print(img_file)
# Out:
# C:/Users/poscoedu_ph/AI 기초/data/NEU Metal Surface Defects Data/test/Crazing/Cr_1.bmp

# %%
img = np.array(image_pil)   # array로 변환
img = img / 255.            #0~1 사이로 리스케일링
img = img[tf.newaxis, ...]  #앞쪽에 배열 추가,  1,200,200,3 
img

pred = model.predict(img)   #모델을 활용하여 img 예측, pred는 6개 클래스에 대한 확률값
print(pred)

classes = np.argmax(pred)  # 가장 확률이 높은 인덱스(라벨) 확인해 classes 변수에 저장
print(classes)

confidence = round(np.max(pred) * 100, 2) # 확률값 100% 기준으로 계산
print(confidence)

names = labels[classes]  # 예측한 라벨을 names에 저장
title = "{} : {}".format(names, confidence)
plt.title(title)
# plt.imshow(img, "gray")   # 에러 => imshow 입력데이터는 (행,열,차원(컬러/흑백)) 구조를 가지므로 (1,200,200,3)  중 1을 제외해야 함
plt.imshow(np.squeeze(img), "gray")  #200,200 이미지 출력,,, np.squeeze()함수는 크기가 1인 axis 제거하여 (200,200,3) 으로 변경
plt.show()
# Out:
# [[9.9992335e-01 4.2219228e-10 3.7490900e-05 2.3804272e-05 1.4621551e-05
#   7.0960436e-07]]
# 0
# 99.99
